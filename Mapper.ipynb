# %% [markdown]
# https://www.kaggle.com/noriuk/us-education-datasets-unification-project#states_all_extended.csv
# Determine two values: (a) the number of rows where the enrollment in grade 9 to 12 (Column name: GRADES_9_12_G) is less than 5,000 and (b) between 10,000 and 20,000.

# %%
#!/usr/bin/env python
"""mapper.py"""
import sys
import pandas as pd
import numpy as np
import math

# %%
data = pd.read_csv("states_all_extended.csv")

# %%
attribute = data['GRADES_9_12_G']

# %%
for i in range(0, data.size):
    j = i+10
    new_data = attribute.loc[i:j]
    i = i+10
    print(new_data)
    for a in new_data:
        int(a)
        if (a >= 10000 and a <= 20000) or (a < 5000):
            print(a, 1)
# Out:
# 0      196386.0
# 1       30847.0
# 2      175210.0
# 3      123113.0
# 4     1372011.0
# 5      160299.0
# 6      126917.0
# 7       28338.0
# 8       18173.0
# 9      511557.0
# 10     315539.0
# Name: GRADES_9_12_G, dtype: float64
# 18173.0 1
# 1       30847.0
# 2      175210.0
# 3      123113.0
# 4     1372011.0
# 5      160299.0
# 6      126917.0
# 7       28338.0
# 8       18173.0
# 9      511557.0
# 10     315539.0
# 11      43882.0
# Name: GRADES_9_12_G, dtype: float64
# 18173.0 1
# 2      175210.0
# 3      123113.0
# 4     1372011.0
# 5      160299.0
# 6      126917.0
# 7       28338.0
# 8       18173.0
# 9      511557.0
# 10     315539.0
# 11      43882.0
# 12      66541.0
# Name: GRADES_9_12_G, dtype: float64
# 18173.0 1
# 3      123113.0
# 4     1372011.0
# 5      160299.0
# 6      126917.0
# 7       28338.0
# 8       18173.0
# 9      511557.0
# 10     315539.0
# 11      43882.0
# 12      66541.0
# 13     495562.0
# Name: GRADES_9_12_G, dtype: float64
# 18173.0 1
# ...
